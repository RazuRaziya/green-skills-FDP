# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:/Users/Mathematics/OneDrive/Desktop/dataset/power_data.csv")
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
from sklearn.model_selection import train_test_split

# %%
target_y=df["PE"]
features_x=df.drop('PE', axis=1, inplace=False)
features_x.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
 train_x, test_x, train_y, test_y=train_test_split(features_x, target_y, test_size=0.2)

# %%
train_x.shape
# Out:
# (7654, 4)

# %%
test_x.shape
# Out:
# (1914, 4)

# %%
train_x, test_x, train_y, test_y=train_test_split(features_x, target_y, test_size=0.7)
train_x.shape
# Out:
# (2870, 4)

# %%
test_x.shape
# Out:
# (6698, 4)

# %%
train_x, test_x, train_y, test_y=train_test_split(features_x, target_y, test_size=0.4)
train_x.shape
# Out:
# (5740, 4)

# %%
test_x.shape
# Out:
# (3828, 4)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
print('co-efficients:', model.coef_)
print('Intercept:', model.intercept_)
# Out:
# co-efficients: [-1.97717062 -0.2361591   0.06273798 -0.16106902]
# Intercept: 454.2529054564139

# %%
predicted_y=model.predict(test_x)
predicted_y.shape
# Out:
# (3828,)

# %%
from sklearn.metrics import r2_score
print("accuracy:",r2_score(test_y, predicted_y))
# Out:
# accuracy: 0.9267920030394261
